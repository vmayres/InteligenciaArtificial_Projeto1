# %% [markdown]
# # Naive Bayes

# %%
import pandas as pd

# Carregar o dataset a partir do arquivo CSV
file_path = r'C:\Users\victor\OneDrive\Documentos\GitHub\InteligenciaArtificial_Projeto1\Dataset_ECG\ecg.csv'
dataset = pd.read_csv(file_path)

# Exibir as primeiras linhas do dataset para conferir se foi carregado corretamente
dataset.head()
# Out:
#    -0.11252183  -2.8272038  -3.7738969  -4.3497511  -4.376041  -3.4749863  \
# 0    -1.100878   -3.996840   -4.285843   -4.506579  -4.022377   -3.234368
# 1    -0.567088   -2.593450   -3.874230   -4.584095  -4.187449   -3.151462
# 2     0.490473   -1.914407   -3.616364   -4.318823  -4.268016   -3.881110
# 3     0.800232   -0.874252   -2.384761   -3.973292  -4.338224   -3.802422
# 4    -1.507674   -3.574550   -4.478011   -4.408275  -3.321242   -2.105171
#
#    -2.1814082  -1.8182865  -1.2505219  -0.47749208  ...  0.79216787  \
# 0   -1.566126   -0.992258   -0.754680     0.042321  ...    0.538356
# 1   -1.742940   -1.490659   -1.183580    -0.394229  ...    0.886073
# 2   -2.993280   -1.671131   -1.333884    -0.965629  ...    0.350816
# 3   -2.534510   -1.783423   -1.594450    -0.753199  ...    1.148884
# 4   -1.481048   -1.301362   -0.498240    -0.286928  ...    1.089068
#
#    0.93354122  0.79695779  0.57862066  0.2577399  0.22807718  0.12343082  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder 

# Separa saida e entrada do arquivo de treino
entrada = dataset.iloc[:, :-1]
saida = dataset.iloc[:, -1]

# %%
from sklearn.model_selection import train_test_split

#
entrada_treino, entrada_teste, saida_treino, saida_teste = train_test_split(entrada, saida, test_size=0.3)

# %%
from sklearn.naive_bayes import GaussianNB

gaussian = GaussianNB()
gaussian.fit(entrada_treino, saida_treino)
# Out:
# GaussianNB()

# %%
# Fazer previsões
previsao = gaussian.predict(entrada_teste)
print(previsao)

previsao_proba = gaussian.predict_proba(entrada_teste)
print(previsao_proba)
# Out:
# [1. 0. 0. ... 1. 1. 1.]
# [[1.20107027e-076 1.00000000e+000]
#  [1.00000000e+000 3.77988908e-043]
#  [1.00000000e+000 2.98824558e-102]
#  ...
#  [9.11592515e-090 1.00000000e+000]
#  [1.75913016e-025 1.00000000e+000]
#  [7.23082384e-028 1.00000000e+000]]

# %%
def classToArithimia(classe):
    if classe == 0:
        return '0: normal'
    elif classe == 1:
        return '1: anormal'
    else:
        return 'Classe inválida'

# Apply the function to each element in the previsao array
previsao_classes = list(map(classToArithimia, previsao))

# Print the results
print(previsao_classes)
# Out:
# ['1: anormal', '0: normal', '0: normal', '1: anormal', '0: normal', '1: anormal', '0: normal', '0: normal', '0: normal', '1: anormal', '1: anormal', '0: normal', '1: anormal', '0: normal', '1: anormal', '0: normal', '1: anormal', '1: anormal', '0: normal', '0: normal', '0: normal', '0: normal', '0: normal', '1: anormal', '1: anormal', '1: anormal', '0: normal', '1: anormal', '1: anormal', '1: anormal', '1: anormal', '1: anormal', '0: normal', '0: normal', '0: normal', '0: normal', '0: normal', '1: anormal', '1: anormal', '1: anormal', '1: anormal', '0: normal', '1: anormal', '0: normal', '1: anormal', '1: anormal', '1: anormal', '1: anormal', '0: normal', '1: anormal', '1: anormal', '0: normal', '1: anormal', '1: anormal', '0: normal', '0: normal', '0: normal', '1: anormal', '1: anormal', '1: anormal', '1: anormal', '0: normal', '0: normal', '0: normal', '0: normal', '0: normal', '1: anormal', '1: anormal', '0: normal', '0: normal', '1: anormal', '0: normal', '1: anormal', '1: anorma
# ...

# %%
import matplotlib.pyplot as plt

# Convert DataFrame to NumPy array
entrada_teste_np = entrada_teste.values

# Plotar as classes reais
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.scatter(entrada_teste_np[:, 0], entrada_teste_np[:, 1], c=saida_teste, cmap='viridis', alpha=0.5)
plt.title('Classes Reais')
plt.xlabel('Componente Principal 1')
plt.ylabel('Componente Principal 2')

# Plotar as classes previstas
plt.subplot(1, 2, 2)
plt.scatter(entrada_teste_np[:, 0], entrada_teste_np[:, 1], c=previsao, cmap='viridis', alpha=0.5)
plt.title('Classes Previstas')
plt.xlabel('Componente Principal 1')
plt.ylabel('Componente Principal 2')

plt.tight_layout()
plt.show()

# %%
import numpy as np
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

# Calcular as métricas
accuracy = accuracy_score(saida_teste, previsao)
precision = precision_score(saida_teste, previsao)
recall = recall_score(saida_teste, previsao)
f1 = f1_score(saida_teste, previsao)
conf_matrix = confusion_matrix(saida_teste, previsao)

# Exibir os resultados
print(f'Acurácia: {accuracy}')
print(f'Precisão: {precision}')
print(f'Revocação: {recall}')
print(f'F1-Score: {f1}')
print(f'Matriz de Confusão:\n{conf_matrix}')
# Out:
# Acurácia: 0.964
# Precisão: 0.985594237695078
# Revocação: 0.951332560834299
# F1-Score: 0.9681603773584906
# Matriz de Confusão:
# [[625  12]
#  [ 42 821]]
